# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import KFold, train_test_split
from torch.utils.data import DataLoader, Dataset
import numpy as np
import os
from sklearn.utils import shuffle
from sklearn.metrics import roc_auc_score, average_precision_score, matthews_corrcoef
from sklearn.metrics import average_precision_score, coverage_error, label_ranking_loss, hamming_loss,zero_one_loss
from tqdm import tqdm
import warnings
warnings.filterwarnings(action='ignore')

# %%
class RNADataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
 
    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.features)
    
    def __getitem__(self, idx):
        # Retrieve the feature and label at the specified index
        feature_tensor = torch.tensor(self.features[idx], dtype=torch.float32)
        label_tensor = torch.tensor(self.labels[idx], dtype=torch.float32)
        return feature_tensor, label_tensor

# %%
def load_data(file_paths, label_path):
    features = []
    for file in file_paths:
        data = pd.read_csv(file).values

        # Normalize each feature set independently
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(data)  

        # Convert the scaled data to torch.tensor and append to the features list
        features.append(torch.tensor(scaled_data, dtype=torch.float32))

    all_features = torch.cat(features, dim=1)  # Concatenate along the columns

    labels = torch.tensor(pd.read_csv(label_path, header=None).values, dtype=torch.float32)

    return all_features, labels

# %%
def load_data(file_paths, label_path):
    features = []
    for file in file_paths:
        # Read the data from each file and convert to numpy array
        data = pd.read_csv(file).values

        # Normalize each feature set independently
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(data)  # Apply normalization

        # Convert the scaled data to torch.tensor and append to the features list
        features.append(torch.tensor(scaled_data, dtype=torch.float32))

    # Concatenate all feature sets along the feature dimension (columns)
    all_features = torch.cat(features, dim=1)  # Concatenate along the columns

    # Read the labels from the label file and convert to tensor
    labels = torch.tensor(pd.read_csv(label_path, header=None).values, dtype=torch.float32)

    return all_features, labels

# %%
# Define the TextCNN module
class TextCNN(nn.Module):
    def __init__(self, out_channels_1, out_channels_2, out_channels_3):
        super(TextCNN, self).__init__()
        # Define three different convolution layers with different kernel sizes
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=out_channels_1, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=out_channels_2, kernel_size=4, padding=1)
        self.conv3 = nn.Conv1d(in_channels=1, out_channels=out_channels_3, kernel_size=5, padding=1)
        # Define a pooling layer to reduce the output size to 1 using AdaptiveMaxPool1d
        self.pool = nn.AdaptiveMaxPool1d(1)
        # Define a Dropout layer for regularization to prevent overfitting
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        x1 = F.relu(self.conv1(x))
        x2 = F.relu(self.conv2(x))
        x3 = F.relu(self.conv3(x))
        # Apply pooling to each convolutional output and remove the last dimension
        x1 = self.pool(x1).squeeze(-1)
        x2 = self.pool(x2).squeeze(-1)
        x3 = self.pool(x3).squeeze(-1)
        # Concatenate the outputs of the three convolutions
        x = torch.cat([x1, x2, x3], dim=1)
        x = self.dropout(x)
        return x

# Define the BiLSTM module
class BiLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers=2):
        super(BiLSTM, self).__init__()
        # Define a Bi-directional LSTM layer
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(0.3)  
    
    def forward(self, x):
        # Forward pass through the LSTM
        output, _ = self.lstm(x)
        output = self.dropout(output)
        return output[:, -1, :]  

# Define the FeatureModule for handling individual features
class FeatureModule(nn.Module):
    def __init__(self, input_dim, out_channels, bilstm_hidden_dim):
        super(FeatureModule, self).__init__()
        # Initialize the TextCNN and BiLSTM modules
        self.textcnn = TextCNN(out_channels[0], out_channels[1], out_channels[2])
        self.bilstm = BiLSTM(input_dim, bilstm_hidden_dim)
        # Calculate the total dimension after concatenating the outputs
        total_dim = sum(out_channels) + 2 * bilstm_hidden_dim
        # Define the multi-head attention mechanism
        self.attention = nn.MultiheadAttention(embed_dim=total_dim, num_heads=8, batch_first=True)
        # Define the fully connected layer for classification
        self.fc = nn.Linear(total_dim, 9)
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, x):
        # Pass the input through the TextCNN module
        x_textcnn = self.textcnn(x.unsqueeze(1))
        
        # Pass the input through the BiLSTM module
        x_bilstm = self.bilstm(x.unsqueeze(1))
        
        # Concatenate the outputs of TextCNN and BiLSTM
        x_concat = torch.cat([x_textcnn, x_bilstm], dim=1).unsqueeze(1)
        
        # Apply multi-head attention to the concatenated features
        x_attention, _ = self.attention(x_concat, x_concat, x_concat)
        # Apply Dropout to the attention output
        x_attention = self.dropout(x_attention)
        x_fc = self.fc(x_attention.squeeze(1))
        return x_fc


# Define the mRSubLoc model
class mRSubLoc(nn.Module):
    def __init__(self, bilstm_hidden_dim):
        super(mRSubLoc, self).__init__()
        # Initialize feature modules for each type of feature (One-hot, Word2Vec, RNAErnie)
        self.onehot_feature_module = FeatureModule(280, [16, 32, 64], bilstm_hidden_dim)
        self.word2vec_feature_module = FeatureModule(768, [32, 64, 128], bilstm_hidden_dim)
        self.rna_ernie_feature_module = FeatureModule(768, [32, 64, 128], bilstm_hidden_dim)
        
        self.mlp = nn.Sequential(
            nn.Linear(27 , 18),  # First fully connected layer
            nn.ReLU(),  
            nn.Dropout(0.5),  # Dropout layer for regularization
            nn.Linear(18, 9)   
        )

    def forward(self, x):
        onehot_features = x[:, :280]
        word2vec_features = x[:, 280:1048]
        rna_ernie_features = x[:, 1048:]
        
        # Process each feature set through its corresponding feature module
        onehot_prob = torch.sigmoid(self.onehot_feature_module(onehot_features))
        word2vec_prob = torch.sigmoid(self.word2vec_feature_module(word2vec_features))
        rna_ernie_prob = torch.sigmoid(self.rna_ernie_feature_module(rna_ernie_features))
        
        # Concatenate the outputs of all feature modules
        new_features = torch.cat([onehot_prob, word2vec_prob, rna_ernie_prob])
        
        # Pass the concatenated features through the MLP for final classification
        final_output = self.mlp(new_features)
        return final_output

# %%
def calculate_metrics(L, L_pred):
    
    n, m = L.shape  # n: number of samples, m: number of labels

    # Aiming 
    aiming = 0
    for v in range(n):
        intersection = 0
        for h in range(m):
            if L_pred[v, h] == 1 and L[v, h] == 1:
                intersection += 1
        if sum(L_pred[v]) == 0: 
            continue
        aiming += intersection / sum(L_pred[v])  
    aiming /= n

    # Accuracy
    accuracy = 0
    for v in range(n):
        intersection = 0
        union = 0
        for h in range(m):
            if L_pred[v, h] == 1 or L[v, h] == 1:
                union += 1
            if L_pred[v, h] == 1 and L[v, h] == 1:
                intersection += 1
        if union == 0:  
            continue
        accuracy += intersection / union  
    accuracy /= n

    # Coverage 
    coverage = 0
    for v in range(n):
        intersection = 0
        for h in range(m):
            if L_pred[v, h] == 1 and L[v, h] == 1:
                intersection += 1
        if sum(L[v]) == 0:  
            continue
        coverage += intersection / sum(L[v])  
    coverage /= n

    # AbsoluteTrue
    absolute_true = 0
    for v in range(n):
        if list(L_pred[v]) == list(L[v]):  
            absolute_true += 1
    absolute_true /= n

    # AbsoluteFalse 
    absolute_false = 0
    for v in range(n):
        intersection = 0
        union = 0
        for h in range(m):
            if L_pred[v, h] == 1 or L[v, h] == 1:
                union += 1
            if L_pred[v, h] == 1 and L[v, h] == 1:
                intersection += 1
        absolute_false += (union - intersection) / m  
    absolute_false /= n

    return aiming, coverage, accuracy, absolute_true, absolute_false

# %%
def train_and_validate(model, train_loader, val_loader, criterion, optimizer, device):
    best_hamming_loss = float('inf')  # Initialize best Hamming loss as infinity
    best_model_state = None  

    y_true_list = []  
    y_pred_list = []  

    # Training mode
    model.train()  
    for features, labels in train_loader:
        features = features.to(device)  
        labels = labels.to(device)  

        optimizer.zero_grad()  # Clear previous gradients
        outputs = model(features)  # Forward pass through the model
        loss = criterion(outputs, labels)  # Compute the loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update the model parameters

    # Validation mode
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # Disable gradient calculation during validation
        for features, labels in val_loader:
            features = features.to(device)  
            labels = labels.to(device) 
            outputs = model(features)  
            preds = torch.sigmoid(outputs).round()  # Apply sigmoid and round to get binary predictions
            y_true_list.append(labels.cpu().numpy())  # Append true labels to the list
            y_pred_list.append(preds.cpu().numpy())  # Append predicted labels to the list

    # Stack true and predicted labels from the lists to form arrays
    y_true = np.vstack(y_true_list)
    y_pred = np.vstack(y_pred_list)

    # Calculate evaluation metrics
    aiming_value, coverage_value, accuracy_value, absolute_true_value, absolute_false_value = calculate_metrics(y_true, y_pred)

    return aiming_value, coverage_value, accuracy_value, absolute_true_value, absolute_false_value

# %%
def main():
    feature_files = ['../Data/TrainingData_Onehot.csv',
                     '../Data/TrainingData_word2vec.csv',
                     '../Data/TrainingData_RNAErnie.csv']
    label_file = '../Data/TrainingLabel.csv'
    bilstm_hidden_dim = 64  # Hidden dimension for BiLSTM
    batch_size = 32  
    learning_rate = 0.00001  
    k_folds = 5  
    epochs = 100  
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

    # Load data
    features, labels = load_data(feature_files, label_file)
    features, labels = shuffle(features, labels, random_state=43)  

    # Initialize K-Fold cross-validation
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=43)

    global_acc = 0.0  # Variable to track the best global accuracy
    global_best_model = None 

    # Dictionary to store metrics across all folds
    fold_metrics_all = {
        "aiming": [],
        "coverage": [],
        "accuracy": [],
        "absolute_true": [],
        "absolute_false": []
    }

    # K-Fold Cross-Validation outer loop
    for fold, (train_idx, val_idx) in enumerate(kf.split(labels), 1):
        
        # Split the data into training and validation sets
        train_features = features[train_idx]
        val_features = features[val_idx] 
        train_labels = labels[train_idx]
        val_labels = labels[val_idx]

        # DataLoader for training and validation sets
        train_dataset = RNADataset(train_features, train_labels)
        val_dataset = RNADataset(val_features, val_labels)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

        # Instantiate the model
        model = mRSubLoc(
            bilstm_hidden_dim=bilstm_hidden_dim
        ).to(device)

        # Loss function and optimizer
        criterion = nn.BCEWithLogitsLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        # Dictionary to store metrics for each fold
        fold_metrics = {
            "aiming": [],
            "coverage": [],
            "accuracy": [],
            "absolute_true": [],
            "absolute_false": []
        }

        # Loop over epochs for the current fold
        for epoch in range(epochs):
            # Train and validate the model
            aiming_value, coverage_value, accuracy_value, absolute_true_value, absolute_false_value = train_and_validate(
                model, train_loader, val_loader, criterion, optimizer, device)

            # Print metrics for the current fold and epoch
            print(f"Fold {fold}, Epoch {epoch + 1} : "
                  f"Aiming: {aiming_value:.4f}, "
                  f"Coverage: {coverage_value:.4f}, "
                  f"Accuracy: {accuracy_value:.4f}, "
                  f"Absolute True: {absolute_true_value:.4f}, "
                  f"Absolute False: {absolute_false_value:.4f}")

            # Store metrics for each epoch in the current fold
            fold_metrics["aiming"].append(aiming_value)
            fold_metrics["coverage"].append(coverage_value)
            fold_metrics["accuracy"].append(accuracy_value)
            fold_metrics["absolute_true"].append(absolute_true_value)
            fold_metrics["absolute_false"].append(absolute_false_value)

            
            if accuracy_value > global_acc: 
                global_acc = accuracy_value
                global_best_model = model.state_dict()

        # Store the metrics for the current fold in the global dictionary
        for metric in fold_metrics_all:
            fold_metrics_all[metric].append(np.mean(fold_metrics[metric]))

    # Calculate the average metrics across all folds
    avg_fold_metrics = {metric: np.mean(values) for metric, values in fold_metrics_all.items()}
    print(f"\nAverage metrics across all folds: "
          f"Aiming: {avg_fold_metrics['aiming']:.4f}, "
          f"Coverage: {avg_fold_metrics['coverage']:.4f}, "
          f"Accuracy: {avg_fold_metrics['accuracy']:.4f}, "
          f"Absolute True: {avg_fold_metrics['absolute_true']:.4f}, "
          f"Absolute False: {avg_fold_metrics['absolute_false']:.4f}")
# Out:
# Fold 1, Epoch 1 : Aiming: 0.0000, Coverage: 0.0000, Accuracy: 0.0000, Absolute True: 0.0000,Absolute False: 0.3332
# Fold 1, Epoch 2 : Aiming: 0.0000, Coverage: 0.0000, Accuracy: 0.0000, Absolute True: 0.0000,Absolute False: 0.3332
# Fold 1, Epoch 3 : Aiming: 0.0000, Coverage: 0.0000, Accuracy: 0.0000, Absolute True: 0.0000,Absolute False: 0.3332
# Fold 1, Epoch 4 : Aiming: 0.3156, Coverage: 0.0494, Accuracy: 0.0494, Absolute True: 0.0000,Absolute False: 0.2981
# Fold 1, Epoch 5 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 6 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 7 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 8 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 9 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 10 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 11 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 12 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 13 : Aiming: 0.7919, Coverage: 0.4255, Accuracy: 0.4255, Absolute True: 0.2963,Absolute False: 0.2683
# Fold 1, Epoch 14 : Aiming: 0.7677, Coverage: 0.4576, Accuracy: 0.4563, Absolute True: 0.2963,Absolute False: 0.2498
# Fold 1, Epoch 15 : Aiming: 0.7660, Coverage: 0.4876, Accuracy: 0.4851, Absolute True: 0.2963,Absolute False: 0.2294
# Fold 1, Epoch 16 : Aiming: 0.7679, Coverage: 0.5026, Accuracy: 0.4996, Absolute True: 0.2963,Absolute False: 0.2187
# Fold 1, Epoch 17 : Aiming: 0.7726, Coverage: 0.5421, Accuracy: 0.5376, Absolute True: 0.2963,Absolute False: 0.1908
# Fold 1, Epoch 18 : Aiming: 0.7752, Coverage: 0.5792, Accuracy: 0.5724, Absolute True: 0.2963,Absolute False: 0.1646
# Fold 1, Epoch 19 : Aiming: 0.7756, Coverage: 0.5938, Accuracy: 0.5859, Absolute True: 0.2963,Absolute False: 0.1549
# Fold 1, Epoch 20 : Aiming: 0.7761, Coverage: 0.6066, Accuracy: 0.5977, Absolute True: 0.2963,Absolute False: 0.1461
# Fold 1, Epoch 21 : Aiming: 0.7774, Coverage: 0.6403, Accuracy: 0.6298, Absolute True: 0.3431,Absolute False: 0.1220
# Fold 1, Epoch 22 : Aiming: 0.7782, Coverage: 0.6566, Accuracy: 0.6450, Absolute True: 0.3633,Absolute False: 0.1110
# Fold 1, Epoch 23 : Aiming: 0.7777, Coverage: 0.6571, Accuracy: 0.6451, Absolute True: 0.3635,Absolute False: 0.1111
# Fold 1, Epoch 24 : Aiming: 0.7778, Coverage: 0.6569, Accuracy: 0.6450, Absolute True: 0.3635,Absolute False: 0.1111
# Fold 1, Epoch 25 : Aiming: 0.7779, Coverage: 0.6575, Accuracy: 0.6458, Absolute True: 0.3637,Absolute False: 0.1107
# Fold 1, Epoch 26 : Aiming: 0.7781, Coverage: 0.6567, Accuracy: 0.6451, Absolute True: 0.3635,Absolute False: 0.1110
# Fold 1, Epoch 27 : Aiming: 0.7779, Coverage: 0.6573, Accuracy: 0.6455, Absolute True: 0.3640,Absolute False: 0.1109
# Fold 1, Epoch 28 : Aiming: 0.7779, Coverage: 0.6579, Accuracy: 0.6459, Absolute True: 0.3640,Absolute False: 0.1108
# Fold 1, Epoch 29 : Aiming: 0.7777, Coverage: 0.6579, Accuracy: 0.6458, Absolute True: 0.3637,Absolute False: 0.1109
# Fold 1, Epoch 30 : Aiming: 0.7781, Coverage: 0.6576, Accuracy: 0.6458, Absolute True: 0.3642,Absolute False: 0.1107
# Fold 1, Epoch 31 : Aiming: 0.7777, Coverage: 0.6592, Accuracy: 0.6471, Absolute True: 0.3635,Absolute False: 0.1103
# Fold 1, Epoch 32 : Aiming: 0.7778, Coverage: 0.6590, Accuracy: 0.6470, Absolute True: 0.3637,Absolute False: 0.1103
# Fold 1, Epoch 33 : Aiming: 0.7776, Coverage: 0.6592, Accuracy: 0.6471, Absolute True: 0.3635,Absolute False: 0.1103
# Fold 1, Epoch 34 : Aiming: 0.7780, Coverage: 0.6587, Accuracy: 0.6468, Absolute True: 0.3640,Absolute False: 0.1103
# Fold 1, Epoch 35 : Aiming: 0.7782, Coverage: 0.6586, Accuracy: 0.6468, Absolute True: 0.3635,Absolute False: 0.1103
# Fold 1, Epoch 36 : Aiming: 0.7776, Coverage: 0.6604, Accuracy: 0.6483, Absolute True: 0.3640,Absolute False: 0.1098
# Fold 1, Epoch 37 : Aiming: 0.7780, Coverage: 0.6602, Accuracy: 0.6484, Absolute True: 0.3635,Absolute False: 0.1097
# Fold 1, Epoch 38 : Aiming: 0.7769, Coverage: 0.6620, Accuracy: 0.6494, Absolute True: 0.3642,Absolute False: 0.1095
# Fold 1, Epoch 39 : Aiming: 0.7766, Coverage: 0.6622, Accuracy: 0.6496, Absolute True: 0.3640,Absolute False: 0.1094
# Fold 1, Epoch 40 : Aiming: 0.7763, Coverage: 0.6626, Accuracy: 0.6498, Absolute True: 0.3640,Absolute False: 0.1094
# Fold 1, Epoch 41 : Aiming: 0.7762, Coverage: 0.6632, Accuracy: 0.6504, Absolute True: 0.3642,Absolute False: 0.1092
# Fold 1, Epoch 42 : Aiming: 0.7765, Coverage: 0.6625, Accuracy: 0.6499, Absolute True: 0.3633,Absolute False: 0.1093
# Fold 1, Epoch 43 : Aiming: 0.7760, Coverage: 0.6634, Accuracy: 0.6505, Absolute True: 0.3635,Absolute False: 0.1091
# Fold 1, Epoch 44 : Aiming: 0.7775, Coverage: 0.6612, Accuracy: 0.6491, Absolute True: 0.3633,Absolute False: 0.1095
# Fold 1, Epoch 45 : Aiming: 0.7739, Coverage: 0.6642, Accuracy: 0.6506, Absolute True: 0.3635,Absolute False: 0.1093
# Fold 1, Epoch 46 : Aiming: 0.7751, Coverage: 0.6643, Accuracy: 0.6510, Absolute True: 0.3640,Absolute False: 0.1090
# Fold 1, Epoch 47 : Aiming: 0.7726, Coverage: 0.6649, Accuracy: 0.6507, Absolute True: 0.3637,Absolute False: 0.1093
# Fold 1, Epoch 48 : Aiming: 0.7724, Coverage: 0.6649, Accuracy: 0.6507, Absolute True: 0.3633,Absolute False: 0.1093
# Fold 1, Epoch 49 : Aiming: 0.7724, Coverage: 0.6653, Accuracy: 0.6511, Absolute True: 0.3637,Absolute False: 0.1092
# Fold 1, Epoch 50 : Aiming: 0.7713, Coverage: 0.6660, Accuracy: 0.6513, Absolute True: 0.3633,Absolute False: 0.1092
# Fold 1, Epoch 51 : Aiming: 0.7701, Coverage: 0.6662, Accuracy: 0.6510, Absolute True: 0.3631,Absolute False: 0.1093
# Fold 1, Epoch 52 : Aiming: 0.7699, Coverage: 0.6665, Accuracy: 0.6512, Absolute True: 0.3633,Absolute False: 0.1093
# Fold 1, Epoch 53 : Aiming: 0.7692, Coverage: 0.6662, Accuracy: 0.6507, Absolute True: 0.3629,Absolute False: 0.1095
# Fold 1, Epoch 54 : Aiming: 0.7660, Coverage: 0.6689, Accuracy: 0.6514, Absolute True: 0.3629,Absolute False: 0.1095
# Fold 1, Epoch 55 : Aiming: 0.7694, Coverage: 0.6664, Accuracy: 0.6512, Absolute True: 0.3633,Absolute False: 0.1093
# Fold 1, Epoch 56 : Aiming: 0.7631, Coverage: 0.6703, Accuracy: 0.6512, Absolute True: 0.3626,Absolute False: 0.1097
# Fold 1, Epoch 57 : Aiming: 0.7645, Coverage: 0.6684, Accuracy: 0.6503, Absolute True: 0.3622,Absolute False: 0.1100
# Fold 1, Epoch 58 : Aiming: 0.7662, Coverage: 0.6681, Accuracy: 0.6509, Absolute True: 0.3626,Absolute False: 0.1096
# Fold 1, Epoch 59 : Aiming: 0.7644, Coverage: 0.6694, Accuracy: 0.6510, Absolute True: 0.3629,Absolute False: 0.1097
# Fold 1, Epoch 60 : Aiming: 0.7642, Coverage: 0.6695, Accuracy: 0.6512, Absolute True: 0.3633,Absolute False: 0.1096
# Fold 1, Epoch 61 : Aiming: 0.7645, Coverage: 0.6695, Accuracy: 0.6512, Absolute True: 0.3633,Absolute False: 0.1094
# Fold 1, Epoch 62 : Aiming: 0.7614, Coverage: 0.6707, Accuracy: 0.6506, Absolute True: 0.3622,Absolute False: 0.1100
# Fold 1, Epoch 63 : Aiming: 0.7607, Coverage: 0.6726, Accuracy: 0.6513, Absolute True: 0.3633,Absolute False: 0.1098
# Fold 1, Epoch 64 : Aiming: 0.7600, Coverage: 0.6730, Accuracy: 0.6513, Absolute True: 0.3635,Absolute False: 0.1098
# Fold 1, Epoch 65 : Aiming: 0.7608, Coverage: 0.6723, Accuracy: 0.6513, Absolute True: 0.3637,Absolute False: 0.1096
# Fold 1, Epoch 66 : Aiming: 0.7619, Coverage: 0.6708, Accuracy: 0.6512, Absolute True: 0.3642,Absolute False: 0.1097
# Fold 1, Epoch 67 : Aiming: 0.7603, Coverage: 0.6730, Accuracy: 0.6516, Absolute True: 0.3642,Absolute False: 0.1097
# Fold 1, Epoch 68 : Aiming: 0.7612, Coverage: 0.6707, Accuracy: 0.6506, Absolute True: 0.3633,Absolute False: 0.1098
# Fold 1, Epoch 69 : Aiming: 0.7611, Coverage: 0.6708, Accuracy: 0.6507, Absolute True: 0.3633,Absolute False: 0.1098
# Fold 1, Epoch 70 : Aiming: 0.7602, Coverage: 0.6715, Accuracy: 0.6504, Absolute True: 0.3624,Absolute False: 0.1100
# Fold 1, Epoch 71 : Aiming: 0.7599, Coverage: 0.6723, Accuracy: 0.6510, Absolute True: 0.3633,Absolute False: 0.1097
# Fold 1, Epoch 72 : Aiming: 0.7593, Coverage: 0.6724, Accuracy: 0.6505, Absolute True: 0.3626,Absolute False: 0.1099
# Fold 1, Epoch 73 : Aiming: 0.7588, Coverage: 0.6722, Accuracy: 0.6502, Absolute True: 0.3626,Absolute False: 0.1100
# Fold 1, Epoch 74 : Aiming: 0.7579, Coverage: 0.6729, Accuracy: 0.6501, Absolute True: 0.3620,Absolute False: 0.1100
# Fold 1, Epoch 75 : Aiming: 0.7576, Coverage: 0.6747, Accuracy: 0.6510, Absolute True: 0.3635,Absolute False: 0.1097
# Fold 1, Epoch 76 : Aiming: 0.7600, Coverage: 0.6716, Accuracy: 0.6505, Absolute True: 0.3631,Absolute False: 0.1100
# Fold 1, Epoch 77 : Aiming: 0.7608, Coverage: 0.6707, Accuracy: 0.6503, Absolute True: 0.3635,Absolute False: 0.1098
# Fold 1, Epoch 78 : Aiming: 0.7584, Coverage: 0.6719, Accuracy: 0.6499, Absolute True: 0.3629,Absolute False: 0.1100
# Fold 1, Epoch 79 : Aiming: 0.7573, Coverage: 0.6733, Accuracy: 0.6503, Absolute True: 0.3633,Absolute False: 0.1100
# Fold 1, Epoch 80 : Aiming: 0.7572, Coverage: 0.6730, Accuracy: 0.6499, Absolute True: 0.3626,Absolute False: 0.1100
# Fold 1, Epoch 81 : Aiming: 0.7558, Coverage: 0.6728, Accuracy: 0.6488, Absolute True: 0.3607,Absolute False: 0.1105
# Fold 1, Epoch 82 : Aiming: 0.7572, Coverage: 0.6719, Accuracy: 0.6491, Absolute True: 0.3618,Absolute False: 0.1102
# Fold 1, Epoch 83 : Aiming: 0.7607, Coverage: 0.6699, Accuracy: 0.6495, Absolute True: 0.3620,Absolute False: 0.1099
# Fold 1, Epoch 84 : Aiming: 0.7600, Coverage: 0.6710, Accuracy: 0.6502, Absolute True: 0.3642,Absolute False: 0.1097
# Fold 1, Epoch 85 : Aiming: 0.7561, Coverage: 0.6750, Accuracy: 0.6507, Absolute True: 0.3633,Absolute False: 0.1097
# Fold 1, Epoch 86 : Aiming: 0.7581, Coverage: 0.6723, Accuracy: 0.6499, Absolute True: 0.3629,Absolute False: 0.1098
# Fold 1, Epoch 87 : Aiming: 0.7593, Coverage: 0.6723, Accuracy: 0.6507, Absolute True: 0.3637,Absolute False: 0.1095
# Fold 1, Epoch 88 : Aiming: 0.7585, Coverage: 0.6722, Accuracy: 0.6500, Absolute True: 0.3620,Absolute False: 0.1096
# Fold 1, Epoch 89 : Aiming: 0.7536, Coverage: 0.6742, Accuracy: 0.6486, Absolute True: 0.3598,Absolute False: 0.1104
# Fold 1, Epoch 90 : Aiming: 0.7601, Coverage: 0.6718, Accuracy: 0.6507, Absolute True: 0.3637,Absolute False: 0.1095
# Fold 1, Epoch 91 : Aiming: 0.7519, Coverage: 0.6752, Accuracy: 0.6480, Absolute True: 0.3594,Absolute False: 0.1105
# Fold 1, Epoch 92 : Aiming: 0.7564, Coverage: 0.6743, Accuracy: 0.6503, Absolute True: 0.3629,Absolute False: 0.1096
# Fold 1, Epoch 93 : Aiming: 0.7520, Coverage: 0.6758, Accuracy: 0.6481, Absolute True: 0.3589,Absolute False: 0.1104
# Fold 1, Epoch 94 : Aiming: 0.7576, Coverage: 0.6727, Accuracy: 0.6497, Absolute True: 0.3624,Absolute False: 0.1098
# Fold 1, Epoch 95 : Aiming: 0.7572, Coverage: 0.6722, Accuracy: 0.6492, Absolute True: 0.3616,Absolute False: 0.1099
# Fold 1, Epoch 96 : Aiming: 0.7559, Coverage: 0.6731, Accuracy: 0.6491, Absolute True: 0.3611,Absolute False: 0.1100
# Fold 1, Epoch 97 : Aiming: 0.7579, Coverage: 0.6733, Accuracy: 0.6506, Absolute True: 0.3637,Absolute False: 0.1094
# Fold 1, Epoch 98 : Aiming: 0.7579, Coverage: 0.6728, Accuracy: 0.6500, Absolute True: 0.3633,Absolute False: 0.1096
# Fold 1, Epoch 99 : Aiming: 0.7544, Coverage: 0.6743, Accuracy: 0.6493, Absolute True: 0.3629,Absolute False: 0.1100
# Fold 1, Epoch 100 : Aiming: 0.7582, Coverage: 0.6730, Accuracy: 0.6506, Absolute True: 0.3640,Absolute False: 0.1095
# Fold 2, Epoch 1 : Aiming: 0.5557, Coverage: 0.7106, Accuracy: 0.3761, Absolute True: 0.0000,Absolute False: 0.2923
# Fold 2, Epoch 2 : Aiming: 0.6704, Coverage: 0.6563, Accuracy: 0.4257, Absolute True: 0.0533,Absolute False: 0.2535
# Fold 2, Epoch 3 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 4 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 5 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 6 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 7 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 8 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 9 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 10 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 11 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 12 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 13 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 14 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 15 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 16 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 17 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 18 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 19 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 20 : Aiming: 0.6733, Coverage: 0.6554, Accuracy: 0.4275, Absolute True: 0.0549,Absolute False: 0.2524
# Fold 2, Epoch 21 : Aiming: 0.7774, Coverage: 0.6331, Accuracy: 0.4991, Absolute True: 0.2014,Absolute False: 0.2346
# Fold 2, Epoch 22 : Aiming: 0.7911, Coverage: 0.6288, Accuracy: 0.5071, Absolute True: 0.2186,Absolute False: 0.2326
# Fold 2, Epoch 23 : Aiming: 0.7966, Coverage: 0.6266, Accuracy: 0.5100, Absolute True: 0.2245,Absolute False: 0.2318
# Fold 2, Epoch 24 : Aiming: 0.8210, Coverage: 0.6232, Accuracy: 0.5280, Absolute True: 0.2606,Absolute False: 0.2272
# Fold 2, Epoch 25 : Aiming: 0.8510, Coverage: 0.6112, Accuracy: 0.5431, Absolute True: 0.2946,Absolute False: 0.2226
# Fold 2, Epoch 26 : Aiming: 0.8508, Coverage: 0.6100, Accuracy: 0.5421, Absolute True: 0.2933,Absolute False: 0.2228
# Fold 2, Epoch 27 : Aiming: 0.8506, Coverage: 0.6094, Accuracy: 0.5418, Absolute True: 0.2931,Absolute False: 0.2228
# Fold 2, Epoch 28 : Aiming: 0.8506, Coverage: 0.6083, Accuracy: 0.5411, Absolute True: 0.2924,Absolute False: 0.2230
# Fold 2, Epoch 29 : Aiming: 0.8505, Coverage: 0.6086, Accuracy: 0.5416, Absolute True: 0.2933,Absolute False: 0.2229
# Fold 2, Epoch 30 : Aiming: 0.8500, Coverage: 0.6047, Accuracy: 0.5396, Absolute True: 0.2922,Absolute False: 0.2232
# Fold 2, Epoch 31 : Aiming: 0.8498, Coverage: 0.6054, Accuracy: 0.5400, Absolute True: 0.2924,Absolute False: 0.2231
# Fold 2, Epoch 32 : Aiming: 0.8500, Coverage: 0.6064, Accuracy: 0.5405, Absolute True: 0.2926,Absolute False: 0.2230
# Fold 2, Epoch 33 : Aiming: 0.8499, Coverage: 0.6065, Accuracy: 0.5407, Absolute True: 0.2928,Absolute False: 0.2229
# Fold 2, Epoch 34 : Aiming: 0.8500, Coverage: 0.6068, Accuracy: 0.5409, Absolute True: 0.2926,Absolute False: 0.2229
# Fold 2, Epoch 35 : Aiming: 0.8493, Coverage: 0.6033, Accuracy: 0.5393, Absolute True: 0.2928,Absolute False: 0.2232
# Fold 2, Epoch 36 : Aiming: 0.8500, Coverage: 0.6100, Accuracy: 0.5434, Absolute True: 0.2937,Absolute False: 0.2221
# Fold 2, Epoch 37 : Aiming: 0.8500, Coverage: 0.6072, Accuracy: 0.5417, Absolute True: 0.2931,Absolute False: 0.2225
# Fold 2, Epoch 38 : Aiming: 0.8494, Coverage: 0.6057, Accuracy: 0.5410, Absolute True: 0.2931,Absolute False: 0.2227
# Fold 2, Epoch 39 : Aiming: 0.8476, Coverage: 0.6107, Accuracy: 0.5470, Absolute True: 0.2931,Absolute False: 0.2175
# Fold 2, Epoch 40 : Aiming: 0.8445, Coverage: 0.6274, Accuracy: 0.5617, Absolute True: 0.2933,Absolute False: 0.2072
# Fold 2, Epoch 41 : Aiming: 0.8430, Coverage: 0.6529, Accuracy: 0.5844, Absolute True: 0.2928,Absolute False: 0.1917
# Fold 2, Epoch 42 : Aiming: 0.8416, Coverage: 0.6521, Accuracy: 0.5855, Absolute True: 0.2931,Absolute False: 0.1900
# Fold 2, Epoch 43 : Aiming: 0.8399, Coverage: 0.6693, Accuracy: 0.6024, Absolute True: 0.2952,Absolute False: 0.1774
# Fold 2, Epoch 44 : Aiming: 0.8393, Coverage: 0.6809, Accuracy: 0.6110, Absolute True: 0.2989,Absolute False: 0.1731
# Fold 2, Epoch 45 : Aiming: 0.8358, Coverage: 0.6897, Accuracy: 0.6178, Absolute True: 0.3013,Absolute False: 0.1697
# Fold 2, Epoch 46 : Aiming: 0.8339, Coverage: 0.6792, Accuracy: 0.6118, Absolute True: 0.2998,Absolute False: 0.1720
# Fold 2, Epoch 47 : Aiming: 0.8320, Coverage: 0.6850, Accuracy: 0.6230, Absolute True: 0.3031,Absolute False: 0.1651
# Fold 2, Epoch 48 : Aiming: 0.8258, Coverage: 0.6669, Accuracy: 0.6183, Absolute True: 0.3024,Absolute False: 0.1627
# Fold 2, Epoch 49 : Aiming: 0.8238, Coverage: 0.6629, Accuracy: 0.6175, Absolute True: 0.3029,Absolute False: 0.1617
# Fold 2, Epoch 50 : Aiming: 0.8273, Coverage: 0.6773, Accuracy: 0.6274, Absolute True: 0.3057,Absolute False: 0.1585
# Fold 2, Epoch 51 : Aiming: 0.8283, Coverage: 0.6860, Accuracy: 0.6351, Absolute True: 0.3079,Absolute False: 0.1544
# Fold 2, Epoch 52 : Aiming: 0.8292, Coverage: 0.6936, Accuracy: 0.6418, Absolute True: 0.3096,Absolute False: 0.1513
# Fold 2, Epoch 53 : Aiming: 0.8263, Coverage: 0.6829, Accuracy: 0.6351, Absolute True: 0.3087,Absolute False: 0.1534
# Fold 2, Epoch 54 : Aiming: 0.8248, Coverage: 0.6831, Accuracy: 0.6372, Absolute True: 0.3107,Absolute False: 0.1517
# Fold 2, Epoch 55 : Aiming: 0.8240, Coverage: 0.6824, Accuracy: 0.6378, Absolute True: 0.3096,Absolute False: 0.1505
# Fold 2, Epoch 56 : Aiming: 0.8262, Coverage: 0.7008, Accuracy: 0.6519, Absolute True: 0.3157,Absolute False: 0.1442
# Fold 2, Epoch 57 : Aiming: 0.8195, Coverage: 0.7121, Accuracy: 0.6629, Absolute True: 0.3396,Absolute False: 0.1333
# Fold 2, Epoch 58 : Aiming: 0.8185, Coverage: 0.7132, Accuracy: 0.6644, Absolute True: 0.3427,Absolute False: 0.1310
# Fold 2, Epoch 59 : Aiming: 0.8205, Coverage: 0.7301, Accuracy: 0.6772, Absolute True: 0.3503,Absolute False: 0.1230
# Fold 2, Epoch 60 : Aiming: 0.8193, Coverage: 0.7329, Accuracy: 0.6803, Absolute True: 0.3547,Absolute False: 0.1163
# Fold 2, Epoch 61 : Aiming: 0.8137, Coverage: 0.7330, Accuracy: 0.6829, Absolute True: 0.3608,Absolute False: 0.1074
# Fold 2, Epoch 62 : Aiming: 0.8031, Coverage: 0.7131, Accuracy: 0.6730, Absolute True: 0.3603,Absolute False: 0.1079
# Fold 2, Epoch 63 : Aiming: 0.8083, Coverage: 0.7264, Accuracy: 0.6802, Absolute True: 0.3625,Absolute False: 0.1055
# Fold 2, Epoch 64 : Aiming: 0.8094, Coverage: 0.7306, Accuracy: 0.6827, Absolute True: 0.3632,Absolute False: 0.1046
# Fold 2, Epoch 65 : Aiming: 0.8056, Coverage: 0.7199, Accuracy: 0.6768, Absolute True: 0.3612,Absolute False: 0.1052
# Fold 2, Epoch 66 : Aiming: 0.8077, Coverage: 0.7258, Accuracy: 0.6805, Absolute True: 0.3627,Absolute False: 0.1042
# Fold 2, Epoch 67 : Aiming: 0.8063, Coverage: 0.7271, Accuracy: 0.6816, Absolute True: 0.3645,Absolute False: 0.1034
# Fold 2, Epoch 68 : Aiming: 0.8002, Coverage: 0.7136, Accuracy: 0.6747, Absolute True: 0.3638,Absolute False: 0.1042
# Fold 2, Epoch 69 : Aiming: 0.7942, Coverage: 0.7011, Accuracy: 0.6680, Absolute True: 0.3625,Absolute False: 0.1053
# Fold 2, Epoch 70 : Aiming: 0.7927, Coverage: 0.6976, Accuracy: 0.6663, Absolute True: 0.3625,Absolute False: 0.1056
# Fold 2, Epoch 71 : Aiming: 0.7924, Coverage: 0.6988, Accuracy: 0.6672, Absolute True: 0.3638,Absolute False: 0.1056
# Fold 2, Epoch 72 : Aiming: 0.7935, Coverage: 0.7028, Accuracy: 0.6690, Absolute True: 0.3638,Absolute False: 0.1052
# Fold 2, Epoch 73 : Aiming: 0.7932, Coverage: 0.7033, Accuracy: 0.6695, Absolute True: 0.3642,Absolute False: 0.1052
# Fold 2, Epoch 74 : Aiming: 0.7936, Coverage: 0.7067, Accuracy: 0.6714, Absolute True: 0.3645,Absolute False: 0.1049
# Fold 2, Epoch 75 : Aiming: 0.7963, Coverage: 0.7101, Accuracy: 0.6731, Absolute True: 0.3640,Absolute False: 0.1046
# Fold 2, Epoch 76 : Aiming: 0.7956, Coverage: 0.7095, Accuracy: 0.6731, Absolute True: 0.3649,Absolute False: 0.1045
# Fold 2, Epoch 77 : Aiming: 0.7947, Coverage: 0.7132, Accuracy: 0.6749, Absolute True: 0.3660,Absolute False: 0.1044
# Fold 2, Epoch 78 : Aiming: 0.7943, Coverage: 0.7076, Accuracy: 0.6721, Absolute True: 0.3647,Absolute False: 0.1047
# Fold 2, Epoch 79 : Aiming: 0.7949, Coverage: 0.7253, Accuracy: 0.6807, Absolute True: 0.3688,Absolute False: 0.1039
# Fold 2, Epoch 80 : Aiming: 0.7956, Coverage: 0.7196, Accuracy: 0.6782, Absolute True: 0.3666,Absolute False: 0.1039
# Fold 2, Epoch 81 : Aiming: 0.7941, Coverage: 0.7108, Accuracy: 0.6740, Absolute True: 0.3662,Absolute False: 0.1045
# Fold 2, Epoch 82 : Aiming: 0.7960, Coverage: 0.7111, Accuracy: 0.6739, Absolute True: 0.3645,Absolute False: 0.1047
# Fold 2, Epoch 83 : Aiming: 0.7933, Coverage: 0.7141, Accuracy: 0.6756, Absolute True: 0.3669,Absolute False: 0.1043
# Fold 2, Epoch 84 : Aiming: 0.7930, Coverage: 0.7190, Accuracy: 0.6775, Absolute True: 0.3675,Absolute False: 0.1042
# Fold 2, Epoch 85 : Aiming: 0.7932, Coverage: 0.7204, Accuracy: 0.6783, Absolute True: 0.3684,Absolute False: 0.1042
# Fold 2, Epoch 86 : Aiming: 0.7949, Coverage: 0.7168, Accuracy: 0.6768, Absolute True: 0.3669,Absolute False: 0.1044
# Fold 2, Epoch 87 : Aiming: 0.7935, Coverage: 0.7189, Accuracy: 0.6777, Absolute True: 0.3680,Absolute False: 0.1043
# Fold 2, Epoch 88 : Aiming: 0.7946, Coverage: 0.7188, Accuracy: 0.6778, Absolute True: 0.3682,Absolute False: 0.1043
# Fold 2, Epoch 89 : Aiming: 0.7945, Coverage: 0.7176, Accuracy: 0.6771, Absolute True: 0.3671,Absolute False: 0.1044
# Fold 2, Epoch 90 : Aiming: 0.7938, Coverage: 0.7166, Accuracy: 0.6767, Absolute True: 0.3671,Absolute False: 0.1044
# Fold 2, Epoch 91 : Aiming: 0.7928, Coverage: 0.7215, Accuracy: 0.6787, Absolute True: 0.3682,Absolute False: 0.1044
# Fold 2, Epoch 92 : Aiming: 0.7918, Coverage: 0.7182, Accuracy: 0.6771, Absolute True: 0.3682,Absolute False: 0.1046
# Fold 2, Epoch 93 : Aiming: 0.7920, Coverage: 0.7184, Accuracy: 0.6771, Absolute True: 0.3684,Absolute False: 0.1046
# Fold 2, Epoch 94 : Aiming: 0.7909, Coverage: 0.7222, Accuracy: 0.6789, Absolute True: 0.3699,Absolute False: 0.1044
# Fold 2, Epoch 95 : Aiming: 0.7915, Coverage: 0.7175, Accuracy: 0.6767, Absolute True: 0.3688,Absolute False: 0.1046
# Fold 2, Epoch 96 : Aiming: 0.7913, Coverage: 0.7220, Accuracy: 0.6789, Absolute True: 0.3699,Absolute False: 0.1045
# Fold 2, Epoch 97 : Aiming: 0.7894, Coverage: 0.7277, Accuracy: 0.6818, Absolute True: 0.3734,Absolute False: 0.1040
# Fold 2, Epoch 98 : Aiming: 0.7917, Coverage: 0.7195, Accuracy: 0.6778, Absolute True: 0.3690,Absolute False: 0.1045
# Fold 2, Epoch 99 : Aiming: 0.7930, Coverage: 0.7213, Accuracy: 0.6787, Absolute True: 0.3686,Absolute False: 0.1043
# Fold 2, Epoch 100 : Aiming: 0.7902, Coverage: 0.7249, Accuracy: 0.6803, Absolute True: 0.3710,Absolute False: 0.1041
# Fold 3, Epoch 1 : Aiming: 0.5003, Coverage: 0.6830, Accuracy: 0.3410, Absolute True: 0.0026,Absolute False: 0.3397
# Fold 3, Epoch 2 : Aiming: 0.5846, Coverage: 0.7246, Accuracy: 0.4039, Absolute True: 0.0294,Absolute False: 0.2828
# Fold 3, Epoch 3 : Aiming: 0.5845, Coverage: 0.7246, Accuracy: 0.4038, Absolute True: 0.0294,Absolute False: 0.2829
# Fold 3, Epoch 4 : Aiming: 0.5845, Coverage: 0.7246, Accuracy: 0.4038, Absolute True: 0.0294,Absolute False: 0.2829
# Fold 3, Epoch 5 : Aiming: 0.5845, Coverage: 0.7246, Accuracy: 0.4038, Absolute True: 0.0294,Absolute False: 0.2829
# Fold 3, Epoch 6 : Aiming: 0.6732, Coverage: 0.6916, Accuracy: 0.4683, Absolute True: 0.0479,Absolute False: 0.2266
# Fold 3, Epoch 7 : Aiming: 0.6735, Coverage: 0.6908, Accuracy: 0.4676, Absolute True: 0.0475,Absolute False: 0.2269
# Fold 3, Epoch 8 : Aiming: 0.6735, Coverage: 0.6906, Accuracy: 0.4674, Absolute True: 0.0472,Absolute False: 0.2270
# Fold 3, Epoch 9 : Aiming: 0.6688, Coverage: 0.7057, Accuracy: 0.4808, Absolute True: 0.0472,Absolute False: 0.2178
# Fold 3, Epoch 10 : Aiming: 0.6674, Coverage: 0.7080, Accuracy: 0.4825, Absolute True: 0.0472,Absolute False: 0.2167
# Fold 3, Epoch 11 : Aiming: 0.6672, Coverage: 0.7082, Accuracy: 0.4827, Absolute True: 0.0472,Absolute False: 0.2166
# Fold 3, Epoch 12 : Aiming: 0.7167, Coverage: 0.6592, Accuracy: 0.5184, Absolute True: 0.1550,Absolute False: 0.2036
# Fold 3, Epoch 13 : Aiming: 0.7498, Coverage: 0.6286, Accuracy: 0.5370, Absolute True: 0.2164,Absolute False: 0.1965
# Fold 3, Epoch 14 : Aiming: 0.7514, Coverage: 0.6663, Accuracy: 0.5715, Absolute True: 0.2275,Absolute False: 0.1708
# Fold 3, Epoch 15 : Aiming: 0.7563, Coverage: 0.6749, Accuracy: 0.5899, Absolute True: 0.2571,Absolute False: 0.1568
# Fold 3, Epoch 16 : Aiming: 0.7594, Coverage: 0.6779, Accuracy: 0.6001, Absolute True: 0.2695,Absolute False: 0.1496
# Fold 3, Epoch 17 : Aiming: 0.7657, Coverage: 0.6716, Accuracy: 0.6065, Absolute True: 0.2843,Absolute False: 0.1453
# Fold 3, Epoch 18 : Aiming: 0.7677, Coverage: 0.6882, Accuracy: 0.6296, Absolute True: 0.2998,Absolute False: 0.1293
# Fold 3, Epoch 19 : Aiming: 0.7732, Coverage: 0.6951, Accuracy: 0.6505, Absolute True: 0.3333,Absolute False: 0.1132
# Fold 3, Epoch 20 : Aiming: 0.7816, Coverage: 0.6772, Accuracy: 0.6556, Absolute True: 0.3597,Absolute False: 0.1100
# Fold 3, Epoch 21 : Aiming: 0.7844, Coverage: 0.6677, Accuracy: 0.6550, Absolute True: 0.3666,Absolute False: 0.1095
# Fold 3, Epoch 22 : Aiming: 0.7841, Coverage: 0.6690, Accuracy: 0.6559, Absolute True: 0.3664,Absolute False: 0.1093
# Fold 3, Epoch 23 : Aiming: 0.7840, Coverage: 0.6693, Accuracy: 0.6561, Absolute True: 0.3666,Absolute False: 0.1093
# Fold 3, Epoch 24 : Aiming: 0.7832, Coverage: 0.6700, Accuracy: 0.6565, Absolute True: 0.3669,Absolute False: 0.1093
# Fold 3, Epoch 25 : Aiming: 0.7842, Coverage: 0.6693, Accuracy: 0.6562, Absolute True: 0.3666,Absolute False: 0.1092
# Fold 3, Epoch 26 : Aiming: 0.7832, Coverage: 0.6700, Accuracy: 0.6565, Absolute True: 0.3669,Absolute False: 0.1092
# Fold 3, Epoch 27 : Aiming: 0.7831, Coverage: 0.6702, Accuracy: 0.6566, Absolute True: 0.3666,Absolute False: 0.1092
# Fold 3, Epoch 28 : Aiming: 0.7829, Coverage: 0.6713, Accuracy: 0.6576, Absolute True: 0.3673,Absolute False: 0.1090
# Fold 3, Epoch 29 : Aiming: 0.7830, Coverage: 0.6708, Accuracy: 0.6572, Absolute True: 0.3669,Absolute False: 0.1090
# Fold 3, Epoch 30 : Aiming: 0.7833, Coverage: 0.6709, Accuracy: 0.6576, Absolute True: 0.3673,Absolute False: 0.1088
# Fold 3, Epoch 31 : Aiming: 0.7832, Coverage: 0.6707, Accuracy: 0.6573, Absolute True: 0.3673,Absolute False: 0.1090
# Fold 3, Epoch 32 : Aiming: 0.7836, Coverage: 0.6705, Accuracy: 0.6574, Absolute True: 0.3677,Absolute False: 0.1088
# Fold 3, Epoch 33 : Aiming: 0.7831, Coverage: 0.6712, Accuracy: 0.6577, Absolute True: 0.3673,Absolute False: 0.1087
# Fold 3, Epoch 34 : Aiming: 0.7832, Coverage: 0.6710, Accuracy: 0.6577, Absolute True: 0.3675,Absolute False: 0.1087
# Fold 3, Epoch 35 : Aiming: 0.7829, Coverage: 0.6723, Accuracy: 0.6586, Absolute True: 0.3680,Absolute False: 0.1085
# Fold 3, Epoch 36 : Aiming: 0.7820, Coverage: 0.6736, Accuracy: 0.6593, Absolute True: 0.3677,Absolute False: 0.1083
# Fold 3, Epoch 37 : Aiming: 0.7822, Coverage: 0.6733, Accuracy: 0.6592, Absolute True: 0.3682,Absolute False: 0.1082
# Fold 3, Epoch 38 : Aiming: 0.7818, Coverage: 0.6737, Accuracy: 0.6593, Absolute True: 0.3684,Absolute False: 0.1082
# Fold 3, Epoch 39 : Aiming: 0.7825, Coverage: 0.6725, Accuracy: 0.6587, Absolute True: 0.3682,Absolute False: 0.1084
# Fold 3, Epoch 40 : Aiming: 0.7814, Coverage: 0.6742, Accuracy: 0.6598, Absolute True: 0.3690,Absolute False: 0.1081
# Fold 3, Epoch 41 : Aiming: 0.7814, Coverage: 0.6743, Accuracy: 0.6598, Absolute True: 0.3690,Absolute False: 0.1080
# Fold 3, Epoch 42 : Aiming: 0.7810, Coverage: 0.6736, Accuracy: 0.6591, Absolute True: 0.3688,Absolute False: 0.1084
# Fold 3, Epoch 43 : Aiming: 0.7808, Coverage: 0.6742, Accuracy: 0.6595, Absolute True: 0.3693,Absolute False: 0.1082
# Fold 3, Epoch 44 : Aiming: 0.7810, Coverage: 0.6738, Accuracy: 0.6592, Absolute True: 0.3686,Absolute False: 0.1083
# Fold 3, Epoch 45 : Aiming: 0.7796, Coverage: 0.6759, Accuracy: 0.6605, Absolute True: 0.3703,Absolute False: 0.1080
# Fold 3, Epoch 46 : Aiming: 0.7801, Coverage: 0.6749, Accuracy: 0.6598, Absolute True: 0.3693,Absolute False: 0.1081
# Fold 3, Epoch 47 : Aiming: 0.7807, Coverage: 0.6744, Accuracy: 0.6598, Absolute True: 0.3699,Absolute False: 0.1081
# Fold 3, Epoch 48 : Aiming: 0.7794, Coverage: 0.6759, Accuracy: 0.6605, Absolute True: 0.3703,Absolute False: 0.1079
# Fold 3, Epoch 49 : Aiming: 0.7806, Coverage: 0.6747, Accuracy: 0.6601, Absolute True: 0.3695,Absolute False: 0.1080
# Fold 3, Epoch 50 : Aiming: 0.7791, Coverage: 0.6759, Accuracy: 0.6604, Absolute True: 0.3703,Absolute False: 0.1080
# Fold 3, Epoch 51 : Aiming: 0.7803, Coverage: 0.6746, Accuracy: 0.6599, Absolute True: 0.3703,Absolute False: 0.1081
# Fold 3, Epoch 52 : Aiming: 0.7765, Coverage: 0.6782, Accuracy: 0.6609, Absolute True: 0.3706,Absolute False: 0.1080
# Fold 3, Epoch 53 : Aiming: 0.7782, Coverage: 0.6768, Accuracy: 0.6611, Absolute True: 0.3717,Absolute False: 0.1077
# Fold 3, Epoch 54 : Aiming: 0.7782, Coverage: 0.6770, Accuracy: 0.6611, Absolute True: 0.3717,Absolute False: 0.1077
# Fold 3, Epoch 55 : Aiming: 0.7763, Coverage: 0.6785, Accuracy: 0.6616, Absolute True: 0.3730,Absolute False: 0.1077
# Fold 3, Epoch 56 : Aiming: 0.7752, Coverage: 0.6799, Accuracy: 0.6622, Absolute True: 0.3738,Absolute False: 0.1077
# Fold 3, Epoch 57 : Aiming: 0.7750, Coverage: 0.6814, Accuracy: 0.6634, Absolute True: 0.3764,Absolute False: 0.1072
# Fold 3, Epoch 58 : Aiming: 0.7763, Coverage: 0.6787, Accuracy: 0.6618, Absolute True: 0.3736,Absolute False: 0.1077
# Fold 3, Epoch 59 : Aiming: 0.7780, Coverage: 0.6775, Accuracy: 0.6616, Absolute True: 0.3734,Absolute False: 0.1074
# Fold 3, Epoch 60 : Aiming: 0.7758, Coverage: 0.6802, Accuracy: 0.6629, Absolute True: 0.3756,Absolute False: 0.1072
# Fold 3, Epoch 61 : Aiming: 0.7755, Coverage: 0.6805, Accuracy: 0.6631, Absolute True: 0.3767,Absolute False: 0.1072
# Fold 3, Epoch 62 : Aiming: 0.7757, Coverage: 0.6804, Accuracy: 0.6631, Absolute True: 0.3767,Absolute False: 0.1072
# Fold 3, Epoch 63 : Aiming: 0.7749, Coverage: 0.6810, Accuracy: 0.6631, Absolute True: 0.3758,Absolute False: 0.1074
# Fold 3, Epoch 64 : Aiming: 0.7734, Coverage: 0.6822, Accuracy: 0.6632, Absolute True: 0.3767,Absolute False: 0.1074
# Fold 3, Epoch 65 : Aiming: 0.7721, Coverage: 0.6849, Accuracy: 0.6649, Absolute True: 0.3815,Absolute False: 0.1070
# Fold 3, Epoch 66 : Aiming: 0.7760, Coverage: 0.6805, Accuracy: 0.6635, Absolute True: 0.3782,Absolute False: 0.1070
# Fold 3, Epoch 67 : Aiming: 0.7751, Coverage: 0.6804, Accuracy: 0.6630, Absolute True: 0.3767,Absolute False: 0.1072
# Fold 3, Epoch 68 : Aiming: 0.7735, Coverage: 0.6819, Accuracy: 0.6632, Absolute True: 0.3773,Absolute False: 0.1074
# Fold 3, Epoch 69 : Aiming: 0.7741, Coverage: 0.6823, Accuracy: 0.6640, Absolute True: 0.3793,Absolute False: 0.1070
# Fold 3, Epoch 70 : Aiming: 0.7734, Coverage: 0.6826, Accuracy: 0.6639, Absolute True: 0.3797,Absolute False: 0.1071
# Fold 3, Epoch 71 : Aiming: 0.7748, Coverage: 0.6811, Accuracy: 0.6637, Absolute True: 0.3797,Absolute False: 0.1070
# Fold 3, Epoch 72 : Aiming: 0.7741, Coverage: 0.6820, Accuracy: 0.6637, Absolute True: 0.3788,Absolute False: 0.1070
# Fold 3, Epoch 73 : Aiming: 0.7723, Coverage: 0.6836, Accuracy: 0.6640, Absolute True: 0.3784,Absolute False: 0.1070
# Fold 3, Epoch 74 : Aiming: 0.7748, Coverage: 0.6810, Accuracy: 0.6635, Absolute True: 0.3791,Absolute False: 0.1070
# Fold 3, Epoch 75 : Aiming: 0.7718, Coverage: 0.6841, Accuracy: 0.6643, Absolute True: 0.3808,Absolute False: 0.1070
# Fold 3, Epoch 76 : Aiming: 0.7709, Coverage: 0.6843, Accuracy: 0.6639, Absolute True: 0.3801,Absolute False: 0.1071
# Fold 3, Epoch 77 : Aiming: 0.7718, Coverage: 0.6842, Accuracy: 0.6644, Absolute True: 0.3812,Absolute False: 0.1070
# Fold 3, Epoch 78 : Aiming: 0.7695, Coverage: 0.6856, Accuracy: 0.6644, Absolute True: 0.3819,Absolute False: 0.1070
# Fold 3, Epoch 79 : Aiming: 0.7725, Coverage: 0.6829, Accuracy: 0.6638, Absolute True: 0.3801,Absolute False: 0.1072
# Fold 3, Epoch 80 : Aiming: 0.7702, Coverage: 0.6834, Accuracy: 0.6631, Absolute True: 0.3799,Absolute False: 0.1073
# Fold 3, Epoch 81 : Aiming: 0.7718, Coverage: 0.6837, Accuracy: 0.6643, Absolute True: 0.3823,Absolute False: 0.1069
# Fold 3, Epoch 82 : Aiming: 0.7697, Coverage: 0.6841, Accuracy: 0.6635, Absolute True: 0.3810,Absolute False: 0.1072
# Fold 3, Epoch 83 : Aiming: 0.7733, Coverage: 0.6820, Accuracy: 0.6636, Absolute True: 0.3795,Absolute False: 0.1070
# Fold 3, Epoch 84 : Aiming: 0.7671, Coverage: 0.6858, Accuracy: 0.6631, Absolute True: 0.3801,Absolute False: 0.1075
# Fold 3, Epoch 85 : Aiming: 0.7709, Coverage: 0.6841, Accuracy: 0.6640, Absolute True: 0.3815,Absolute False: 0.1070
# Fold 3, Epoch 86 : Aiming: 0.7717, Coverage: 0.6825, Accuracy: 0.6632, Absolute True: 0.3804,Absolute False: 0.1072
# Fold 3, Epoch 87 : Aiming: 0.7730, Coverage: 0.6807, Accuracy: 0.6626, Absolute True: 0.3788,Absolute False: 0.1072
# Fold 3, Epoch 88 : Aiming: 0.7715, Coverage: 0.6821, Accuracy: 0.6626, Absolute True: 0.3791,Absolute False: 0.1073
# Fold 3, Epoch 89 : Aiming: 0.7721, Coverage: 0.6812, Accuracy: 0.6627, Absolute True: 0.3795,Absolute False: 0.1073
# Fold 3, Epoch 90 : Aiming: 0.7674, Coverage: 0.6847, Accuracy: 0.6626, Absolute True: 0.3801,Absolute False: 0.1076
# Fold 3, Epoch 91 : Aiming: 0.7701, Coverage: 0.6829, Accuracy: 0.6628, Absolute True: 0.3810,Absolute False: 0.1075
# Fold 3, Epoch 92 : Aiming: 0.7696, Coverage: 0.6829, Accuracy: 0.6623, Absolute True: 0.3791,Absolute False: 0.1076
# Fold 3, Epoch 93 : Aiming: 0.7679, Coverage: 0.6845, Accuracy: 0.6625, Absolute True: 0.3799,Absolute False: 0.1076
# Fold 3, Epoch 94 : Aiming: 0.7682, Coverage: 0.6847, Accuracy: 0.6629, Absolute True: 0.3810,Absolute False: 0.1075
# Fold 3, Epoch 95 : Aiming: 0.7696, Coverage: 0.6823, Accuracy: 0.6619, Absolute True: 0.3780,Absolute False: 0.1075
# Fold 3, Epoch 96 : Aiming: 0.7683, Coverage: 0.6834, Accuracy: 0.6620, Absolute True: 0.3788,Absolute False: 0.1077
# Fold 3, Epoch 97 : Aiming: 0.7704, Coverage: 0.6817, Accuracy: 0.6623, Absolute True: 0.3793,Absolute False: 0.1076
# Fold 3, Epoch 98 : Aiming: 0.7673, Coverage: 0.6853, Accuracy: 0.6629, Absolute True: 0.3808,Absolute False: 0.1074
# Fold 3, Epoch 99 : Aiming: 0.7662, Coverage: 0.6860, Accuracy: 0.6629, Absolute True: 0.3804,Absolute False: 0.1075
# Fold 3, Epoch 100 : Aiming: 0.7714, Coverage: 0.6814, Accuracy: 0.6628, Absolute True: 0.3810,Absolute False: 0.1074
# Fold 4, Epoch 1 : Aiming: 0.4352, Coverage: 0.8119, Accuracy: 0.3541, Absolute True: 0.0033,Absolute False: 0.4078
# Fold 4, Epoch 2 : Aiming: 0.4915, Coverage: 0.7850, Accuracy: 0.3763, Absolute True: 0.0000,Absolute False: 0.3451
# Fold 4, Epoch 3 : Aiming: 0.5759, Coverage: 0.7282, Accuracy: 0.3981, Absolute True: 0.0235,Absolute False: 0.2842
# Fold 4, Epoch 4 : Aiming: 0.5759, Coverage: 0.7282, Accuracy: 0.3981, Absolute True: 0.0235,Absolute False: 0.2842
# Fold 4, Epoch 5 : Aiming: 0.5759, Coverage: 0.7282, Accuracy: 0.3981, Absolute True: 0.0235,Absolute False: 0.2842
# Fold 4, Epoch 6 : Aiming: 0.5759, Coverage: 0.7282, Accuracy: 0.3981, Absolute True: 0.0235,Absolute False: 0.2842
# Fold 4, Epoch 7 : Aiming: 0.5759, Coverage: 0.7282, Accuracy: 0.3981, Absolute True: 0.0235,Absolute False: 0.2842
# Fold 4, Epoch 8 : Aiming: 0.5760, Coverage: 0.7287, Accuracy: 0.3986, Absolute True: 0.0235,Absolute False: 0.2839
# Fold 4, Epoch 9 : Aiming: 0.6645, Coverage: 0.7202, Accuracy: 0.4887, Absolute True: 0.0431,Absolute False: 0.2086
# Fold 4, Epoch 10 : Aiming: 0.6653, Coverage: 0.7418, Accuracy: 0.5101, Absolute True: 0.0427,Absolute False: 0.1929
# Fold 4, Epoch 11 : Aiming: 0.6653, Coverage: 0.7421, Accuracy: 0.5104, Absolute True: 0.0427,Absolute False: 0.1927
# Fold 4, Epoch 12 : Aiming: 0.6653, Coverage: 0.7420, Accuracy: 0.5104, Absolute True: 0.0425,Absolute False: 0.1927
# Fold 4, Epoch 13 : Aiming: 0.6651, Coverage: 0.7421, Accuracy: 0.5104, Absolute True: 0.0425,Absolute False: 0.1927
# Fold 4, Epoch 14 : Aiming: 0.6651, Coverage: 0.7420, Accuracy: 0.5104, Absolute True: 0.0425,Absolute False: 0.1927
# Fold 4, Epoch 15 : Aiming: 0.6651, Coverage: 0.7421, Accuracy: 0.5104, Absolute True: 0.0425,Absolute False: 0.1927
# Fold 4, Epoch 16 : Aiming: 0.7800, Coverage: 0.5711, Accuracy: 0.5678, Absolute True: 0.2933,Absolute False: 0.1673
# Fold 4, Epoch 17 : Aiming: 0.7803, Coverage: 0.5688, Accuracy: 0.5661, Absolute True: 0.2928,Absolute False: 0.1678
# Fold 4, Epoch 18 : Aiming: 0.7800, Coverage: 0.5700, Accuracy: 0.5669, Absolute True: 0.2926,Absolute False: 0.1675
# Fold 4, Epoch 19 : Aiming: 0.7804, Coverage: 0.6197, Accuracy: 0.6159, Absolute True: 0.3144,Absolute False: 0.1324
# Fold 4, Epoch 20 : Aiming: 0.7805, Coverage: 0.6195, Accuracy: 0.6158, Absolute True: 0.3146,Absolute False: 0.1323
# Fold 4, Epoch 21 : Aiming: 0.7805, Coverage: 0.6185, Accuracy: 0.6150, Absolute True: 0.3144,Absolute False: 0.1326
# Fold 4, Epoch 22 : Aiming: 0.7769, Coverage: 0.6337, Accuracy: 0.6268, Absolute True: 0.3309,Absolute False: 0.1244
# Fold 4, Epoch 23 : Aiming: 0.7710, Coverage: 0.6576, Accuracy: 0.6453, Absolute True: 0.3623,Absolute False: 0.1107
# Fold 4, Epoch 24 : Aiming: 0.7708, Coverage: 0.6579, Accuracy: 0.6454, Absolute True: 0.3627,Absolute False: 0.1108
# Fold 4, Epoch 25 : Aiming: 0.7673, Coverage: 0.6606, Accuracy: 0.6449, Absolute True: 0.3638,Absolute False: 0.1114
# Fold 4, Epoch 26 : Aiming: 0.7480, Coverage: 0.6774, Accuracy: 0.6434, Absolute True: 0.3680,Absolute False: 0.1145
# Fold 4, Epoch 27 : Aiming: 0.7481, Coverage: 0.6758, Accuracy: 0.6423, Absolute True: 0.3673,Absolute False: 0.1149
# Fold 4, Epoch 28 : Aiming: 0.7474, Coverage: 0.6781, Accuracy: 0.6436, Absolute True: 0.3675,Absolute False: 0.1146
# Fold 4, Epoch 29 : Aiming: 0.7478, Coverage: 0.6776, Accuracy: 0.6436, Absolute True: 0.3675,Absolute False: 0.1144
# Fold 4, Epoch 30 : Aiming: 0.7478, Coverage: 0.6781, Accuracy: 0.6439, Absolute True: 0.3675,Absolute False: 0.1144
# Fold 4, Epoch 31 : Aiming: 0.7477, Coverage: 0.6785, Accuracy: 0.6442, Absolute True: 0.3677,Absolute False: 0.1143
# Fold 4, Epoch 32 : Aiming: 0.7472, Coverage: 0.6799, Accuracy: 0.6453, Absolute True: 0.3684,Absolute False: 0.1140
# Fold 4, Epoch 33 : Aiming: 0.7476, Coverage: 0.6786, Accuracy: 0.6445, Absolute True: 0.3677,Absolute False: 0.1142
# Fold 4, Epoch 34 : Aiming: 0.7465, Coverage: 0.6817, Accuracy: 0.6466, Absolute True: 0.3686,Absolute False: 0.1136
# Fold 4, Epoch 35 : Aiming: 0.7468, Coverage: 0.6806, Accuracy: 0.6460, Absolute True: 0.3682,Absolute False: 0.1138
# Fold 4, Epoch 36 : Aiming: 0.7465, Coverage: 0.6816, Accuracy: 0.6465, Absolute True: 0.3688,Absolute False: 0.1135
# Fold 4, Epoch 37 : Aiming: 0.7465, Coverage: 0.6830, Accuracy: 0.6478, Absolute True: 0.3690,Absolute False: 0.1131
# Fold 4, Epoch 38 : Aiming: 0.7462, Coverage: 0.6834, Accuracy: 0.6483, Absolute True: 0.3697,Absolute False: 0.1130
# Fold 4, Epoch 39 : Aiming: 0.7467, Coverage: 0.6822, Accuracy: 0.6475, Absolute True: 0.3682,Absolute False: 0.1131
# Fold 4, Epoch 40 : Aiming: 0.7461, Coverage: 0.6837, Accuracy: 0.6484, Absolute True: 0.3697,Absolute False: 0.1129
# Fold 4, Epoch 41 : Aiming: 0.7465, Coverage: 0.6834, Accuracy: 0.6486, Absolute True: 0.3695,Absolute False: 0.1127
# Fold 4, Epoch 42 : Aiming: 0.7465, Coverage: 0.6838, Accuracy: 0.6491, Absolute True: 0.3701,Absolute False: 0.1125
# Fold 4, Epoch 43 : Aiming: 0.7469, Coverage: 0.6827, Accuracy: 0.6483, Absolute True: 0.3695,Absolute False: 0.1126
# Fold 4, Epoch 44 : Aiming: 0.7464, Coverage: 0.6839, Accuracy: 0.6492, Absolute True: 0.3701,Absolute False: 0.1123
# Fold 4, Epoch 45 : Aiming: 0.7466, Coverage: 0.6839, Accuracy: 0.6494, Absolute True: 0.3706,Absolute False: 0.1122
# Fold 4, Epoch 46 : Aiming: 0.7466, Coverage: 0.6839, Accuracy: 0.6495, Absolute True: 0.3710,Absolute False: 0.1119
# Fold 4, Epoch 47 : Aiming: 0.7473, Coverage: 0.6831, Accuracy: 0.6492, Absolute True: 0.3708,Absolute False: 0.1120
# Fold 4, Epoch 48 : Aiming: 0.7459, Coverage: 0.6849, Accuracy: 0.6500, Absolute True: 0.3706,Absolute False: 0.1118
# Fold 4, Epoch 49 : Aiming: 0.7462, Coverage: 0.6843, Accuracy: 0.6497, Absolute True: 0.3706,Absolute False: 0.1120
# Fold 4, Epoch 50 : Aiming: 0.7447, Coverage: 0.6856, Accuracy: 0.6500, Absolute True: 0.3712,Absolute False: 0.1119
# Fold 4, Epoch 51 : Aiming: 0.7453, Coverage: 0.6873, Accuracy: 0.6513, Absolute True: 0.3710,Absolute False: 0.1112
# Fold 4, Epoch 52 : Aiming: 0.7472, Coverage: 0.6826, Accuracy: 0.6497, Absolute True: 0.3706,Absolute False: 0.1112
# Fold 4, Epoch 53 : Aiming: 0.7465, Coverage: 0.6844, Accuracy: 0.6504, Absolute True: 0.3706,Absolute False: 0.1111
# Fold 4, Epoch 54 : Aiming: 0.7470, Coverage: 0.6855, Accuracy: 0.6516, Absolute True: 0.3738,Absolute False: 0.1103
# Fold 4, Epoch 55 : Aiming: 0.7455, Coverage: 0.6863, Accuracy: 0.6512, Absolute True: 0.3710,Absolute False: 0.1109
# Fold 4, Epoch 56 : Aiming: 0.7464, Coverage: 0.6854, Accuracy: 0.6513, Absolute True: 0.3732,Absolute False: 0.1106
# Fold 4, Epoch 57 : Aiming: 0.7448, Coverage: 0.6875, Accuracy: 0.6519, Absolute True: 0.3725,Absolute False: 0.1107
# Fold 4, Epoch 58 : Aiming: 0.7463, Coverage: 0.6867, Accuracy: 0.6526, Absolute True: 0.3767,Absolute False: 0.1099
# Fold 4, Epoch 59 : Aiming: 0.7445, Coverage: 0.6884, Accuracy: 0.6528, Absolute True: 0.3749,Absolute False: 0.1103
# Fold 4, Epoch 60 : Aiming: 0.7448, Coverage: 0.6883, Accuracy: 0.6531, Absolute True: 0.3767,Absolute False: 0.1099
# Fold 4, Epoch 61 : Aiming: 0.7455, Coverage: 0.6880, Accuracy: 0.6538, Absolute True: 0.3799,Absolute False: 0.1092
# Fold 4, Epoch 62 : Aiming: 0.7476, Coverage: 0.6854, Accuracy: 0.6534, Absolute True: 0.3812,Absolute False: 0.1089
# Fold 4, Epoch 63 : Aiming: 0.7467, Coverage: 0.6871, Accuracy: 0.6538, Absolute True: 0.3806,Absolute False: 0.1090
# Fold 4, Epoch 64 : Aiming: 0.7452, Coverage: 0.6892, Accuracy: 0.6549, Absolute True: 0.3836,Absolute False: 0.1088
# Fold 4, Epoch 65 : Aiming: 0.7455, Coverage: 0.6887, Accuracy: 0.6546, Absolute True: 0.3830,Absolute False: 0.1088
# Fold 4, Epoch 66 : Aiming: 0.7457, Coverage: 0.6880, Accuracy: 0.6544, Absolute True: 0.3828,Absolute False: 0.1087
# Fold 4, Epoch 67 : Aiming: 0.7464, Coverage: 0.6865, Accuracy: 0.6536, Absolute True: 0.3819,Absolute False: 0.1088
# Fold 4, Epoch 68 : Aiming: 0.7452, Coverage: 0.6893, Accuracy: 0.6551, Absolute True: 0.3838,Absolute False: 0.1086
# Fold 4, Epoch 69 : Aiming: 0.7444, Coverage: 0.6912, Accuracy: 0.6557, Absolute True: 0.3845,Absolute False: 0.1084
# Fold 4, Epoch 70 : Aiming: 0.7440, Coverage: 0.6928, Accuracy: 0.6562, Absolute True: 0.3838,Absolute False: 0.1083
# Fold 4, Epoch 71 : Aiming: 0.7452, Coverage: 0.6906, Accuracy: 0.6561, Absolute True: 0.3880,Absolute False: 0.1075
# Fold 4, Epoch 72 : Aiming: 0.7437, Coverage: 0.6945, Accuracy: 0.6573, Absolute True: 0.3865,Absolute False: 0.1076
# Fold 4, Epoch 73 : Aiming: 0.7450, Coverage: 0.6903, Accuracy: 0.6561, Absolute True: 0.3871,Absolute False: 0.1076
# Fold 4, Epoch 74 : Aiming: 0.7446, Coverage: 0.6911, Accuracy: 0.6565, Absolute True: 0.3880,Absolute False: 0.1072
# Fold 4, Epoch 75 : Aiming: 0.7434, Coverage: 0.6943, Accuracy: 0.6576, Absolute True: 0.3875,Absolute False: 0.1074
# Fold 4, Epoch 76 : Aiming: 0.7452, Coverage: 0.6919, Accuracy: 0.6572, Absolute True: 0.3893,Absolute False: 0.1069
# Fold 4, Epoch 77 : Aiming: 0.7446, Coverage: 0.6911, Accuracy: 0.6563, Absolute True: 0.3880,Absolute False: 0.1076
# Fold 4, Epoch 78 : Aiming: 0.7452, Coverage: 0.6898, Accuracy: 0.6561, Absolute True: 0.3886,Absolute False: 0.1070
# Fold 4, Epoch 79 : Aiming: 0.7453, Coverage: 0.6905, Accuracy: 0.6565, Absolute True: 0.3895,Absolute False: 0.1067
# Fold 4, Epoch 80 : Aiming: 0.7473, Coverage: 0.6887, Accuracy: 0.6566, Absolute True: 0.3902,Absolute False: 0.1067
# Fold 4, Epoch 81 : Aiming: 0.7460, Coverage: 0.6897, Accuracy: 0.6570, Absolute True: 0.3928,Absolute False: 0.1064
# Fold 4, Epoch 82 : Aiming: 0.7471, Coverage: 0.6881, Accuracy: 0.6564, Absolute True: 0.3906,Absolute False: 0.1069
# Fold 4, Epoch 83 : Aiming: 0.7477, Coverage: 0.6870, Accuracy: 0.6562, Absolute True: 0.3910,Absolute False: 0.1068
# Fold 4, Epoch 84 : Aiming: 0.7458, Coverage: 0.6905, Accuracy: 0.6572, Absolute True: 0.3906,Absolute False: 0.1065
# Fold 4, Epoch 85 : Aiming: 0.7471, Coverage: 0.6884, Accuracy: 0.6565, Absolute True: 0.3906,Absolute False: 0.1066
# Fold 4, Epoch 86 : Aiming: 0.7437, Coverage: 0.6923, Accuracy: 0.6568, Absolute True: 0.3889,Absolute False: 0.1070
# Fold 4, Epoch 87 : Aiming: 0.7465, Coverage: 0.6901, Accuracy: 0.6572, Absolute True: 0.3889,Absolute False: 0.1068
# Fold 4, Epoch 88 : Aiming: 0.7449, Coverage: 0.6940, Accuracy: 0.6580, Absolute True: 0.3884,Absolute False: 0.1068
# Fold 4, Epoch 89 : Aiming: 0.7490, Coverage: 0.6852, Accuracy: 0.6554, Absolute True: 0.3889,Absolute False: 0.1070
# Fold 4, Epoch 90 : Aiming: 0.7500, Coverage: 0.6850, Accuracy: 0.6560, Absolute True: 0.3904,Absolute False: 0.1067
# Fold 4, Epoch 91 : Aiming: 0.7474, Coverage: 0.6899, Accuracy: 0.6575, Absolute True: 0.3891,Absolute False: 0.1067
# Fold 4, Epoch 92 : Aiming: 0.7504, Coverage: 0.6847, Accuracy: 0.6560, Absolute True: 0.3889,Absolute False: 0.1069
# Fold 4, Epoch 93 : Aiming: 0.7510, Coverage: 0.6837, Accuracy: 0.6560, Absolute True: 0.3880,Absolute False: 0.1067
# Fold 4, Epoch 94 : Aiming: 0.7518, Coverage: 0.6828, Accuracy: 0.6557, Absolute True: 0.3867,Absolute False: 0.1069
# Fold 4, Epoch 95 : Aiming: 0.7482, Coverage: 0.6863, Accuracy: 0.6559, Absolute True: 0.3867,Absolute False: 0.1071
# Fold 4, Epoch 96 : Aiming: 0.7488, Coverage: 0.6888, Accuracy: 0.6568, Absolute True: 0.3821,Absolute False: 0.1074
# Fold 4, Epoch 97 : Aiming: 0.7548, Coverage: 0.6798, Accuracy: 0.6549, Absolute True: 0.3782,Absolute False: 0.1078
# Fold 4, Epoch 98 : Aiming: 0.7580, Coverage: 0.6753, Accuracy: 0.6534, Absolute True: 0.3734,Absolute False: 0.1086
# Fold 4, Epoch 99 : Aiming: 0.7562, Coverage: 0.6802, Accuracy: 0.6546, Absolute True: 0.3710,Absolute False: 0.1086
# Fold 4, Epoch 100 : Aiming: 0.7550, Coverage: 0.6776, Accuracy: 0.6526, Absolute True: 0.3682,Absolute False: 0.1094
# Fold 5, Epoch 1 : Aiming: 0.3967, Coverage: 0.4934, Accuracy: 0.2435, Absolute True: 0.0000,Absolute False: 0.4034
# Fold 5, Epoch 2 : Aiming: 0.3967, Coverage: 0.4934, Accuracy: 0.2435, Absolute True: 0.0000,Absolute False: 0.4034
# Fold 5, Epoch 3 : Aiming: 0.4727, Coverage: 0.4847, Accuracy: 0.2997, Absolute True: 0.0000,Absolute False: 0.3306
# Fold 5, Epoch 4 : Aiming: 0.7318, Coverage: 0.5314, Accuracy: 0.5164, Absolute True: 0.3009,Absolute False: 0.2206
# Fold 5, Epoch 5 : Aiming: 0.7758, Coverage: 0.5168, Accuracy: 0.5131, Absolute True: 0.3009,Absolute False: 0.2124
# Fold 5, Epoch 6 : Aiming: 0.7762, Coverage: 0.5171, Accuracy: 0.5134, Absolute True: 0.3009,Absolute False: 0.2122
# Fold 5, Epoch 7 : Aiming: 0.7763, Coverage: 0.5169, Accuracy: 0.5134, Absolute True: 0.3009,Absolute False: 0.2121
# Fold 5, Epoch 8 : Aiming: 0.7765, Coverage: 0.5169, Accuracy: 0.5134, Absolute True: 0.3009,Absolute False: 0.2121
# Fold 5, Epoch 9 : Aiming: 0.7767, Coverage: 0.5166, Accuracy: 0.5132, Absolute True: 0.3009,Absolute False: 0.2122
# Fold 5, Epoch 10 : Aiming: 0.7971, Coverage: 0.4794, Accuracy: 0.4793, Absolute True: 0.3009,Absolute False: 0.2333
# Fold 5, Epoch 11 : Aiming: 0.7971, Coverage: 0.4794, Accuracy: 0.4793, Absolute True: 0.3009,Absolute False: 0.2333
# Fold 5, Epoch 12 : Aiming: 0.7971, Coverage: 0.4794, Accuracy: 0.4793, Absolute True: 0.3009,Absolute False: 0.2333
# Fold 5, Epoch 13 : Aiming: 0.7971, Coverage: 0.4797, Accuracy: 0.4796, Absolute True: 0.3009,Absolute False: 0.2331
# Fold 5, Epoch 14 : Aiming: 0.7971, Coverage: 0.4798, Accuracy: 0.4798, Absolute True: 0.3009,Absolute False: 0.2330
# Fold 5, Epoch 15 : Aiming: 0.7971, Coverage: 0.4801, Accuracy: 0.4800, Absolute True: 0.3009,Absolute False: 0.2329
# Fold 5, Epoch 16 : Aiming: 0.7972, Coverage: 0.4811, Accuracy: 0.4809, Absolute True: 0.3009,Absolute False: 0.2326
# Fold 5, Epoch 17 : Aiming: 0.7971, Coverage: 0.4814, Accuracy: 0.4812, Absolute True: 0.3009,Absolute False: 0.2325
# Fold 5, Epoch 18 : Aiming: 0.7970, Coverage: 0.4814, Accuracy: 0.4812, Absolute True: 0.3009,Absolute False: 0.2325
# Fold 5, Epoch 19 : Aiming: 0.7969, Coverage: 0.4821, Accuracy: 0.4818, Absolute True: 0.3009,Absolute False: 0.2321
# Fold 5, Epoch 20 : Aiming: 0.7891, Coverage: 0.5380, Accuracy: 0.5356, Absolute True: 0.3009,Absolute False: 0.1944
# Fold 5, Epoch 21 : Aiming: 0.7838, Coverage: 0.5531, Accuracy: 0.5485, Absolute True: 0.3009,Absolute False: 0.1858
# Fold 5, Epoch 22 : Aiming: 0.7825, Coverage: 0.5566, Accuracy: 0.5516, Absolute True: 0.3009,Absolute False: 0.1839
# Fold 5, Epoch 23 : Aiming: 0.7824, Coverage: 0.5566, Accuracy: 0.5515, Absolute True: 0.3009,Absolute False: 0.1841
# Fold 5, Epoch 24 : Aiming: 0.7834, Coverage: 0.5876, Accuracy: 0.5808, Absolute True: 0.3009,Absolute False: 0.1620
# Fold 5, Epoch 25 : Aiming: 0.7828, Coverage: 0.6006, Accuracy: 0.5926, Absolute True: 0.3009,Absolute False: 0.1538
# Fold 5, Epoch 26 : Aiming: 0.7826, Coverage: 0.6150, Accuracy: 0.6062, Absolute True: 0.3059,Absolute False: 0.1438
# Fold 5, Epoch 27 : Aiming: 0.7815, Coverage: 0.6385, Accuracy: 0.6278, Absolute True: 0.3314,Absolute False: 0.1279
# Fold 5, Epoch 28 : Aiming: 0.7822, Coverage: 0.6444, Accuracy: 0.6336, Absolute True: 0.3412,Absolute False: 0.1235
# Fold 5, Epoch 29 : Aiming: 0.7827, Coverage: 0.6466, Accuracy: 0.6358, Absolute True: 0.3455,Absolute False: 0.1217
# Fold 5, Epoch 30 : Aiming: 0.7823, Coverage: 0.6544, Accuracy: 0.6428, Absolute True: 0.3523,Absolute False: 0.1168
# Fold 5, Epoch 31 : Aiming: 0.7820, Coverage: 0.6576, Accuracy: 0.6455, Absolute True: 0.3553,Absolute False: 0.1149
# Fold 5, Epoch 32 : Aiming: 0.7820, Coverage: 0.6621, Accuracy: 0.6497, Absolute True: 0.3616,Absolute False: 0.1119
# Fold 5, Epoch 33 : Aiming: 0.7826, Coverage: 0.6643, Accuracy: 0.6521, Absolute True: 0.3636,Absolute False: 0.1099
# Fold 5, Epoch 34 : Aiming: 0.7823, Coverage: 0.6655, Accuracy: 0.6530, Absolute True: 0.3642,Absolute False: 0.1096
# Fold 5, Epoch 35 : Aiming: 0.7826, Coverage: 0.6651, Accuracy: 0.6528, Absolute True: 0.3642,Absolute False: 0.1096
# Fold 5, Epoch 36 : Aiming: 0.7826, Coverage: 0.6655, Accuracy: 0.6532, Absolute True: 0.3647,Absolute False: 0.1094
# Fold 5, Epoch 37 : Aiming: 0.7826, Coverage: 0.6658, Accuracy: 0.6535, Absolute True: 0.3649,Absolute False: 0.1093
# Fold 5, Epoch 38 : Aiming: 0.7828, Coverage: 0.6658, Accuracy: 0.6536, Absolute True: 0.3651,Absolute False: 0.1092
# Fold 5, Epoch 39 : Aiming: 0.7825, Coverage: 0.6661, Accuracy: 0.6538, Absolute True: 0.3651,Absolute False: 0.1092
# Fold 5, Epoch 40 : Aiming: 0.7827, Coverage: 0.6663, Accuracy: 0.6541, Absolute True: 0.3653,Absolute False: 0.1090
# Fold 5, Epoch 41 : Aiming: 0.7828, Coverage: 0.6663, Accuracy: 0.6542, Absolute True: 0.3656,Absolute False: 0.1090
# Fold 5, Epoch 42 : Aiming: 0.7826, Coverage: 0.6666, Accuracy: 0.6543, Absolute True: 0.3653,Absolute False: 0.1090
# Fold 5, Epoch 43 : Aiming: 0.7826, Coverage: 0.6669, Accuracy: 0.6546, Absolute True: 0.3651,Absolute False: 0.1088
# Fold 5, Epoch 44 : Aiming: 0.7826, Coverage: 0.6675, Accuracy: 0.6552, Absolute True: 0.3658,Absolute False: 0.1087
# Fold 5, Epoch 45 : Aiming: 0.7822, Coverage: 0.6682, Accuracy: 0.6557, Absolute True: 0.3660,Absolute False: 0.1085
# Fold 5, Epoch 46 : Aiming: 0.7822, Coverage: 0.6695, Accuracy: 0.6567, Absolute True: 0.3662,Absolute False: 0.1082
# Fold 5, Epoch 47 : Aiming: 0.7826, Coverage: 0.6684, Accuracy: 0.6560, Absolute True: 0.3660,Absolute False: 0.1083
# Fold 5, Epoch 48 : Aiming: 0.7825, Coverage: 0.6694, Accuracy: 0.6568, Absolute True: 0.3664,Absolute False: 0.1081
# Fold 5, Epoch 49 : Aiming: 0.7831, Coverage: 0.6694, Accuracy: 0.6572, Absolute True: 0.3666,Absolute False: 0.1078
# Fold 5, Epoch 50 : Aiming: 0.7821, Coverage: 0.6704, Accuracy: 0.6576, Absolute True: 0.3671,Absolute False: 0.1079
# Fold 5, Epoch 51 : Aiming: 0.7826, Coverage: 0.6704, Accuracy: 0.6577, Absolute True: 0.3669,Absolute False: 0.1077
# Fold 5, Epoch 52 : Aiming: 0.7822, Coverage: 0.6714, Accuracy: 0.6585, Absolute True: 0.3673,Absolute False: 0.1076
# Fold 5, Epoch 53 : Aiming: 0.7822, Coverage: 0.6713, Accuracy: 0.6583, Absolute True: 0.3673,Absolute False: 0.1077
# Fold 5, Epoch 54 : Aiming: 0.7818, Coverage: 0.6720, Accuracy: 0.6588, Absolute True: 0.3677,Absolute False: 0.1075
# Fold 5, Epoch 55 : Aiming: 0.7816, Coverage: 0.6722, Accuracy: 0.6589, Absolute True: 0.3680,Absolute False: 0.1075
# Fold 5, Epoch 56 : Aiming: 0.7817, Coverage: 0.6715, Accuracy: 0.6584, Absolute True: 0.3671,Absolute False: 0.1077
# Fold 5, Epoch 57 : Aiming: 0.7811, Coverage: 0.6734, Accuracy: 0.6595, Absolute True: 0.3686,Absolute False: 0.1074
# Fold 5, Epoch 58 : Aiming: 0.7809, Coverage: 0.6741, Accuracy: 0.6601, Absolute True: 0.3693,Absolute False: 0.1072
# Fold 5, Epoch 59 : Aiming: 0.7807, Coverage: 0.6737, Accuracy: 0.6596, Absolute True: 0.3684,Absolute False: 0.1074
# Fold 5, Epoch 60 : Aiming: 0.7805, Coverage: 0.6749, Accuracy: 0.6606, Absolute True: 0.3699,Absolute False: 0.1072
# Fold 5, Epoch 61 : Aiming: 0.7807, Coverage: 0.6741, Accuracy: 0.6599, Absolute True: 0.3688,Absolute False: 0.1073
# Fold 5, Epoch 62 : Aiming: 0.7805, Coverage: 0.6744, Accuracy: 0.6600, Absolute True: 0.3688,Absolute False: 0.1074
# Fold 5, Epoch 63 : Aiming: 0.7806, Coverage: 0.6746, Accuracy: 0.6604, Absolute True: 0.3688,Absolute False: 0.1072
# Fold 5, Epoch 64 : Aiming: 0.7806, Coverage: 0.6752, Accuracy: 0.6610, Absolute True: 0.3699,Absolute False: 0.1071
# Fold 5, Epoch 65 : Aiming: 0.7807, Coverage: 0.6748, Accuracy: 0.6608, Absolute True: 0.3697,Absolute False: 0.1071
# Fold 5, Epoch 66 : Aiming: 0.7802, Coverage: 0.6751, Accuracy: 0.6605, Absolute True: 0.3693,Absolute False: 0.1073
# Fold 5, Epoch 67 : Aiming: 0.7798, Coverage: 0.6760, Accuracy: 0.6612, Absolute True: 0.3706,Absolute False: 0.1072
# Fold 5, Epoch 68 : Aiming: 0.7808, Coverage: 0.6743, Accuracy: 0.6603, Absolute True: 0.3686,Absolute False: 0.1072
# Fold 5, Epoch 69 : Aiming: 0.7799, Coverage: 0.6763, Accuracy: 0.6614, Absolute True: 0.3708,Absolute False: 0.1071
# Fold 5, Epoch 70 : Aiming: 0.7788, Coverage: 0.6763, Accuracy: 0.6615, Absolute True: 0.3714,Absolute False: 0.1062
# Fold 5, Epoch 71 : Aiming: 0.7796, Coverage: 0.6754, Accuracy: 0.6613, Absolute True: 0.3717,Absolute False: 0.1050
# Fold 5, Epoch 72 : Aiming: 0.7788, Coverage: 0.6751, Accuracy: 0.6606, Absolute True: 0.3703,Absolute False: 0.1044
# Fold 5, Epoch 73 : Aiming: 0.7790, Coverage: 0.6744, Accuracy: 0.6602, Absolute True: 0.3699,Absolute False: 0.1045
# Fold 5, Epoch 74 : Aiming: 0.7781, Coverage: 0.6756, Accuracy: 0.6609, Absolute True: 0.3712,Absolute False: 0.1036
# Fold 5, Epoch 75 : Aiming: 0.7787, Coverage: 0.6768, Accuracy: 0.6619, Absolute True: 0.3723,Absolute False: 0.1035
# Fold 5, Epoch 76 : Aiming: 0.7779, Coverage: 0.6760, Accuracy: 0.6609, Absolute True: 0.3710,Absolute False: 0.1029
# Fold 5, Epoch 77 : Aiming: 0.7786, Coverage: 0.6779, Accuracy: 0.6619, Absolute True: 0.3706,Absolute False: 0.1025
# Fold 5, Epoch 78 : Aiming: 0.7787, Coverage: 0.6806, Accuracy: 0.6629, Absolute True: 0.3710,Absolute False: 0.1023
# Fold 5, Epoch 79 : Aiming: 0.7783, Coverage: 0.6798, Accuracy: 0.6624, Absolute True: 0.3708,Absolute False: 0.1022
# Fold 5, Epoch 80 : Aiming: 0.7807, Coverage: 0.6808, Accuracy: 0.6636, Absolute True: 0.3708,Absolute False: 0.1024
# Fold 5, Epoch 81 : Aiming: 0.7796, Coverage: 0.6791, Accuracy: 0.6625, Absolute True: 0.3703,Absolute False: 0.1018
# Fold 5, Epoch 82 : Aiming: 0.7806, Coverage: 0.6845, Accuracy: 0.6651, Absolute True: 0.3710,Absolute False: 0.1010
# Fold 5, Epoch 83 : Aiming: 0.7801, Coverage: 0.6845, Accuracy: 0.6651, Absolute True: 0.3708,Absolute False: 0.1008
# Fold 5, Epoch 84 : Aiming: 0.7796, Coverage: 0.6854, Accuracy: 0.6655, Absolute True: 0.3723,Absolute False: 0.1014
# Fold 5, Epoch 85 : Aiming: 0.7796, Coverage: 0.6861, Accuracy: 0.6654, Absolute True: 0.3703,Absolute False: 0.0998
# Fold 5, Epoch 86 : Aiming: 0.7810, Coverage: 0.6854, Accuracy: 0.6653, Absolute True: 0.3703,Absolute False: 0.1005
# Fold 5, Epoch 87 : Aiming: 0.7808, Coverage: 0.6847, Accuracy: 0.6647, Absolute True: 0.3697,Absolute False: 0.1002
# Fold 5, Epoch 88 : Aiming: 0.7806, Coverage: 0.6842, Accuracy: 0.6642, Absolute True: 0.3695,Absolute False: 0.1004
# Fold 5, Epoch 89 : Aiming: 0.7817, Coverage: 0.6838, Accuracy: 0.6643, Absolute True: 0.3695,Absolute False: 0.1000
# Fold 5, Epoch 90 : Aiming: 0.7801, Coverage: 0.6852, Accuracy: 0.6648, Absolute True: 0.3710,Absolute False: 0.0992
# Fold 5, Epoch 91 : Aiming: 0.7799, Coverage: 0.6866, Accuracy: 0.6659, Absolute True: 0.3719,Absolute False: 0.0991
# Fold 5, Epoch 92 : Aiming: 0.7804, Coverage: 0.6893, Accuracy: 0.6673, Absolute True: 0.3732,Absolute False: 0.0985
# Fold 5, Epoch 93 : Aiming: 0.7810, Coverage: 0.6896, Accuracy: 0.6676, Absolute True: 0.3730,Absolute False: 0.0987
# Fold 5, Epoch 94 : Aiming: 0.7801, Coverage: 0.6911, Accuracy: 0.6685, Absolute True: 0.3743,Absolute False: 0.0977
# Fold 5, Epoch 95 : Aiming: 0.7790, Coverage: 0.6865, Accuracy: 0.6658, Absolute True: 0.3727,Absolute False: 0.0977
# Fold 5, Epoch 96 : Aiming: 0.7798, Coverage: 0.6925, Accuracy: 0.6689, Absolute True: 0.3736,Absolute False: 0.0973
# Fold 5, Epoch 97 : Aiming: 0.7812, Coverage: 0.6910, Accuracy: 0.6687, Absolute True: 0.3743,Absolute False: 0.0975
# Fold 5, Epoch 98 : Aiming: 0.7801, Coverage: 0.6939, Accuracy: 0.6697, Absolute True: 0.3749,Absolute False: 0.0972
# Fold 5, Epoch 99 : Aiming: 0.7809, Coverage: 0.6948, Accuracy: 0.6701, Absolute True: 0.3747,Absolute False: 0.0969
# Fold 5, Epoch 100 : Aiming: 0.7820, Coverage: 0.6947, Accuracy: 0.6710, Absolute True: 0.3764,Absolute False: 0.0967
#
# Average metrics across all folds: Aiming: 0.7569, Coverage: 0.6579, Accuracy: 0.6092, Absolute True: 0.3205, Absolute False: 0.1415
# Saving model to models\RNAErnie+Onehot+Word2Vec.pth
# Best model saved with Acc: 0.6829
